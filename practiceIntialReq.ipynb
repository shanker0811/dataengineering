# %%
import requests as req;
import pandas as pd
res=req.get('https://jsonplaceholder.typicode.com/users')
if(res.status_code==200):
    data=res.json()
    dataFrame=pd.DataFrame(data)
   
    pd.set_option(display.max_rows,150)
    print(dataFrame.head(5))
    print(dataFrame.tail(5))
# Out:
#    id              name   username                      email  \
# 0   1     Leanne Graham       Bret          Sincere@april.biz
# 1   2      Ervin Howell  Antonette          Shanna@melissa.tv
# 2   3  Clementine Bauch   Samantha         Nathan@yesenia.net
# 3   4  Patricia Lebsack   Karianne  Julianne.OConner@kory.org
# 4   5  Chelsey Dietrich     Kamren   Lucio_Hettinger@annie.ca
#
#                                              address                  phone  \
# 0  {'street': 'Kulas Light', 'suite': 'Apt. 556',...  1-770-736-8031 x56442
# 1  {'street': 'Victor Plains', 'suite': 'Suite 87...    010-692-6593 x09125
# 2  {'street': 'Douglas Extension', 'suite': 'Suit...         1-463-123-4447
# 3  {'street': 'Hoeger Mall', 'suite': 'Apt. 692',...      493-170-9623 x156
# 4  {'street': 'Skiles Walks', 'suite': 'Suite 351...          (254)954-1289
#
#          website                                            company
# ...

# %%
# dataFrame.loc[0]
print(dataFrame.columns)
print(len(dataFrame['username']),list(dataFrame.shape)[0])
# Out:
# Index(['id', 'name', 'username', 'email', 'address', 'phone', 'website',
#        'company'],
#       dtype='str')
# 10 10

# %%
# Question 2 :
dataFrame.shape
dataFrame.info()
dataFrame.describe()
# dataFrame.loc[0:,['name','email','phone']]
# print(dataFrame['company'])
print(dataFrame['address'])
list_of_citites=set(map(lambda x:x['city'],dataFrame['address']))
print(list_of_citites)
with open('practiceIntialReq.json','w') as f:
    print('File is present')
    f.write(dataFrame.to_json(orient='records'))

dataFrame.to_csv('practiceIntialReq.csv',index=False)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        10 non-null     int64
#  1   name      10 non-null     str
#  2   username  10 non-null     str
#  3   email     10 non-null     str
#  4   address   10 non-null     object
#  5   phone     10 non-null     str
#  6   website   10 non-null     str
#  7   company   10 non-null     object
# dtypes: int64(1), object(2), str(5)
# memory usage: 772.0+ bytes
# 0    {'street': 'Kulas Light', 'suite': 'Apt. 556',...
# 1    {'street': 'Victor Plains', 'suite': 'Suite 87...
# 2    {'street': 'Douglas Extension', 'suite': 'Suit...
# 3    {'street': 'Hoeger Mall', 'suite': 'Apt. 692',...
# 4    {'street': 'Skiles Walks', 'suite': 'Suite 351...
# 5    {'street': 'Norberto Crossing', 'suite': 'Apt....
# 6    {'street': 'Rex Trail', 'suite': 'Suite 280', ...
# ...
